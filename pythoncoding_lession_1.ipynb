# %% [markdown]
# <a href="https://colab.research.google.com/github/chunglq/DotNET_Developer/blob/master/pythoncoding_lession_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Bài Thu Hoạch số 1
# - **Khá ổn** ...
# ##Dự Án Cá Nhân
# - **Mục Tiêu**: Xây dựng ứng dụng
# >  good to be

# %%
print("This is the first time I work on google")
